# %% [markdown]
# ### Загрузка данных и импортирование библиотеки `pandas`

# %%
import pandas as pd

# Создаем словарь с данными о собаках (20 записей)
data = {
    'Name': ['Сноу', 'Рекс', 'Макс', 'Луна', 'Джек', 'Мило', 'Бэйли', 'Лола', 'Тедди', 'Макс',
             'Бентли', 'Джесси', 'Чарли', 'Максимус', 'Оливер', 'Чарли', 'Луи', 'Белль', 'Сади', 'Сэнди'],
    'Breed': ['Лабрадор', 'Бульдог', 'Далматин', 'Ши-тцу', 'Йоркширский терьер', 'Лабрадор', 'Чихуахуа', 'Шарпей', 'Бассет-хаунд', 'Померанский',
              'Золотистый ретривер', 'Бордер-колли', 'Боксер', 'Ротвейлер', 'Доберман', 'Шиба-ину', 'Бостон-терьер', 'Френч бульдог', 'Хаски', 'Акита'],
    'Color': ['Шоколадный', 'Палевый', 'Черно-белый', 'Белый', 'Серый', 'Абрикосовый', 'Черный', 'Коричневый', 'Трехцветный', 'Оранжевый',
              'Золотистый', 'Черно-белый', 'Тигровый', 'Черный и рыжий', 'Черный и коричневый', 'Трехцветный', 'Черно-белый', 'Белый', 'Серо-белый', 'Коричневый'],
    'Height (cm)': [60, 40, 55, 25, 20, 58, 20, 40, 30, 25, 60, 50, 55, 70, 45, 30, 25, 35, 45, 60],
    'Weight (kg)': [30, 25, 20, 5, 3, 27, 3, 15, 10, 4, 25, 18, 30, 40, 12, 6, 5, 8, 12, 30],
    'Date of Birth': ['2015-02-10', '2018-06-05', '2017-11-20', '2019-04-15', '2020-09-30',
                      '2016-03-25', '2019-08-12', '2018-01-03', '2020-05-19', '2017-09-28',
                      '2016-07-14', '2019-02-08', '2017-04-22', '2015-09-07', '2016-12-30',
                      '2018-11-17', '2020-03-08', '2019-10-12', '2016-06-23', '2015-08-02']
}

# Создаем датафрейм из словаря
dogs = pd.DataFrame(data)

# Выводим датафрейм
print(dogs)
# Out:
#         Name                Breed                Color  Height (cm)  \
# 0       Сноу             Лабрадор           Шоколадный           60
# 1       Рекс              Бульдог              Палевый           40
# 2       Макс             Далматин          Черно-белый           55
# 3       Луна               Ши-тцу                Белый           25
# 4       Джек   Йоркширский терьер                Серый           20
# 5       Мило             Лабрадор          Абрикосовый           58
# 6      Бэйли             Чихуахуа               Черный           20
# 7       Лола               Шарпей           Коричневый           40
# 8      Тедди         Бассет-хаунд          Трехцветный           30
# 9       Макс          Померанский            Оранжевый           25
# 10    Бентли  Золотистый ретривер           Золотистый           60
# 11    Джесси         Бордер-колли          Черно-белый           50
# 12     Чарли               Боксер             Тигровый           55
# 13  Максимус            Ротвейлер       Черный и рыжий           70
# 14    Оливер             Доберман  Черный и коричневый           45
# 15     Чарли             Шиба-ину          Трехцветный           30
# 16       Луи        Бостон-терьер          Черно-белый           25
# 17     Белль        Френч бульдог                Белый           35
# 18      Сади                Хаски           Серо-белый           45
# 19     Сэнди                Акита           Коричневый           60
#
#     Weight (kg) Date of Birth
# 0            30    2015-02-10
# 1            25    2018-06-05
# 2            20    2017-11-20
# 3             5    2019-04-15
# 4             3    2020-09-30
# 5            27    2016-03-25
# 6             3    2019-08-12
# 7            15    2018-01-03
# 8            10    2020-05-19
# 9             4    2017-09-28
# 10           25    2016-07-14
# 11           18    2019-02-08
# 12           30    2017-04-22
# 13           40    2015-09-07
# 14           12    2016-12-30
# 15            6    2018-11-17
# 16            5    2020-03-08
# 17            8    2019-10-12
# 18           12    2016-06-23
# 19           30    2015-08-02

# %% [markdown]
# ### Обзор датафрейма

# %%
dogs.head()
# Out:
#    Name               Breed        Color  Height (cm)  Weight (kg)  \
# 0  Сноу            Лабрадор   Шоколадный           60           30
# 1  Рекс             Бульдог      Палевый           40           25
# 2  Макс            Далматин  Черно-белый           55           20
# 3  Луна              Ши-тцу        Белый           25            5
# 4  Джек  Йоркширский терьер        Серый           20            3
#
#   Date of Birth
# 0    2015-02-10
# 1    2018-06-05
# 2    2017-11-20
# 3    2019-04-15
# 4    2020-09-30

# %%
dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           20 non-null     object
#  1   Breed          20 non-null     object
#  2   Color          20 non-null     object
#  3   Height (cm)    20 non-null     int64
#  4   Weight (kg)    20 non-null     int64
#  5   Date of Birth  20 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %%
dogs.shape
# Out:
# (20, 6)

# %%
dogs.values
# Out:
# array([['Сноу', 'Лабрадор', 'Шоколадный', 60, 30, '2015-02-10'],
#        ['Рекс', 'Бульдог', 'Палевый', 40, 25, '2018-06-05'],
#        ['Макс', 'Далматин', 'Черно-белый', 55, 20, '2017-11-20'],
#        ['Луна', 'Ши-тцу', 'Белый', 25, 5, '2019-04-15'],
#        ['Джек', 'Йоркширский терьер', 'Серый', 20, 3, '2020-09-30'],
#        ['Мило', 'Лабрадор', 'Абрикосовый', 58, 27, '2016-03-25'],
#        ['Бэйли', 'Чихуахуа', 'Черный', 20, 3, '2019-08-12'],
#        ['Лола', 'Шарпей', 'Коричневый', 40, 15, '2018-01-03'],
#        ['Тедди', 'Бассет-хаунд', 'Трехцветный', 30, 10, '2020-05-19'],
#        ['Макс', 'Померанский', 'Оранжевый', 25, 4, '2017-09-28'],
#        ['Бентли', 'Золотистый ретривер', 'Золотистый', 60, 25,
#         '2016-07-14'],
#        ['Джесси', 'Бордер-колли', 'Черно-белый', 50, 18, '2019-02-08'],
#        ['Чарли', 'Боксер', 'Тигровый', 55, 30, '2017-04-22'],
#        ['Максимус', 'Ротвейлер', 'Черный и рыжий', 70, 40, '2015-09-07'],
#        ['Оливер', 'Доберман', 'Черный и коричневый', 45, 12,
#         '2016-12-30'],
#        ['Чарли', 'Шиба-ину', 'Трехцветный', 30, 6, '2018-11-17'],
#        ['Луи', 'Бостон-терьер', 'Черно-белый', 25, 5, '2020-03-08'],
#        ['Белль', 'Френч бульдог', 'Белый', 35, 8, '2019-10-12'],
#        ['Сади', 'Хаски', 'Серо-белый', 45, 12, '2016-06-23'],
#        ['Сэнди', 'Акита', 'Коричневый', 60, 30, '2015-08-02']],
#       dtype=object)

# %%
dogs.describe()
# Out:
#        Height (cm)  Weight (kg)
# count    20.000000    20.000000
# mean     42.400000    16.400000
# std      15.574608    11.287627
# min      20.000000     3.000000
# 25%      28.750000     5.750000
# 50%      42.500000    13.500000
# 75%      55.750000    25.500000
# max      70.000000    40.000000

# %%
dogs.columns
# Out:
# Index(['Name', 'Breed', 'Color', 'Height (cm)', 'Weight (kg)',
#        'Date of Birth'],
#       dtype='object')

# %%
dogs.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %% [markdown]
# ### Сортировка и выборка

# %%
dogs.sort_values("Weight (kg)")
# Out:
#         Name                Breed                Color  Height (cm)  \
# 4       Джек   Йоркширский терьер                Серый           20
# 6      Бэйли             Чихуахуа               Черный           20
# 9       Макс          Померанский            Оранжевый           25
# 3       Луна               Ши-тцу                Белый           25
# 16       Луи        Бостон-терьер          Черно-белый           25
# 15     Чарли             Шиба-ину          Трехцветный           30
# 17     Белль        Френч бульдог                Белый           35
# 8      Тедди         Бассет-хаунд          Трехцветный           30
# 18      Сади                Хаски           Серо-белый           45
# 14    Оливер             Доберман  Черный и коричневый           45
# 7       Лола               Шарпей           Коричневый           40
# 11    Джесси         Бордер-колли          Черно-белый           50
# 2       Макс             Далматин          Черно-белый           55
# 1       Рекс              Бульдог              Палевый           40
# 10    Бентли  Золотистый ретривер           Золотистый           60
# 5       Мило             Лабрадор          Абрикосовый           58
# 0       Сноу             Лабрадор           Шоколадный           60
# 12     Чарли               Боксер             Тигровый           55
# 19     Сэнди                Акита           Коричневый           60
# 13  Максимус            Ротвейлер       Черный и рыжий           70
#
#     Weight (kg) Date of Birth
# 4             3    2020-09-30
# 6             3    2019-08-12
# 9             4    2017-09-28
# 3             5    2019-04-15
# 16            5    2020-03-08
# 15            6    2018-11-17
# 17            8    2019-10-12
# 8            10    2020-05-19
# 18           12    2016-06-23
# 14           12    2016-12-30
# 7            15    2018-01-03
# 11           18    2019-02-08
# 2            20    2017-11-20
# 1            25    2018-06-05
# 10           25    2016-07-14
# 5            27    2016-03-25
# 0            30    2015-02-10
# 12           30    2017-04-22
# 19           30    2015-08-02
# 13           40    2015-09-07

# %%
dogs.sort_values("Weight (kg)", ascending=False)
# Out:
#         Name                Breed                Color  Height (cm)  \
# 13  Максимус            Ротвейлер       Черный и рыжий           70
# 0       Сноу             Лабрадор           Шоколадный           60
# 12     Чарли               Боксер             Тигровый           55
# 19     Сэнди                Акита           Коричневый           60
# 5       Мило             Лабрадор          Абрикосовый           58
# 1       Рекс              Бульдог              Палевый           40
# 10    Бентли  Золотистый ретривер           Золотистый           60
# 2       Макс             Далматин          Черно-белый           55
# 11    Джесси         Бордер-колли          Черно-белый           50
# 7       Лола               Шарпей           Коричневый           40
# 14    Оливер             Доберман  Черный и коричневый           45
# 18      Сади                Хаски           Серо-белый           45
# 8      Тедди         Бассет-хаунд          Трехцветный           30
# 17     Белль        Френч бульдог                Белый           35
# 15     Чарли             Шиба-ину          Трехцветный           30
# 3       Луна               Ши-тцу                Белый           25
# 16       Луи        Бостон-терьер          Черно-белый           25
# 9       Макс          Померанский            Оранжевый           25
# 4       Джек   Йоркширский терьер                Серый           20
# 6      Бэйли             Чихуахуа               Черный           20
#
#     Weight (kg) Date of Birth
# 13           40    2015-09-07
# 0            30    2015-02-10
# 12           30    2017-04-22
# 19           30    2015-08-02
# 5            27    2016-03-25
# 1            25    2018-06-05
# 10           25    2016-07-14
# 2            20    2017-11-20
# 11           18    2019-02-08
# 7            15    2018-01-03
# 14           12    2016-12-30
# 18           12    2016-06-23
# 8            10    2020-05-19
# 17            8    2019-10-12
# 15            6    2018-11-17
# 3             5    2019-04-15
# 16            5    2020-03-08
# 9             4    2017-09-28
# 4             3    2020-09-30
# 6             3    2019-08-12

# %%
dogs.sort_values(["Weight (kg)", "Height (cm)"])
# Out:
#         Name                Breed                Color  Height (cm)  \
# 4       Джек   Йоркширский терьер                Серый           20
# 6      Бэйли             Чихуахуа               Черный           20
# 9       Макс          Померанский            Оранжевый           25
# 3       Луна               Ши-тцу                Белый           25
# 16       Луи        Бостон-терьер          Черно-белый           25
# 15     Чарли             Шиба-ину          Трехцветный           30
# 17     Белль        Френч бульдог                Белый           35
# 8      Тедди         Бассет-хаунд          Трехцветный           30
# 14    Оливер             Доберман  Черный и коричневый           45
# 18      Сади                Хаски           Серо-белый           45
# 7       Лола               Шарпей           Коричневый           40
# 11    Джесси         Бордер-колли          Черно-белый           50
# 2       Макс             Далматин          Черно-белый           55
# 1       Рекс              Бульдог              Палевый           40
# 10    Бентли  Золотистый ретривер           Золотистый           60
# 5       Мило             Лабрадор          Абрикосовый           58
# 12     Чарли               Боксер             Тигровый           55
# 0       Сноу             Лабрадор           Шоколадный           60
# 19     Сэнди                Акита           Коричневый           60
# 13  Максимус            Ротвейлер       Черный и рыжий           70
#
#     Weight (kg) Date of Birth
# 4             3    2020-09-30
# 6             3    2019-08-12
# 9             4    2017-09-28
# 3             5    2019-04-15
# 16            5    2020-03-08
# 15            6    2018-11-17
# 17            8    2019-10-12
# 8            10    2020-05-19
# 14           12    2016-12-30
# 18           12    2016-06-23
# 7            15    2018-01-03
# 11           18    2019-02-08
# 2            20    2017-11-20
# 1            25    2018-06-05
# 10           25    2016-07-14
# 5            27    2016-03-25
# 12           30    2017-04-22
# 0            30    2015-02-10
# 19           30    2015-08-02
# 13           40    2015-09-07

# %%
dogs.sort_values(["Weight (kg)", "Height (cm)"], ascending=[True, False])
# Out:
#         Name                Breed                Color  Height (cm)  \
# 4       Джек   Йоркширский терьер                Серый           20
# 6      Бэйли             Чихуахуа               Черный           20
# 9       Макс          Померанский            Оранжевый           25
# 3       Луна               Ши-тцу                Белый           25
# 16       Луи        Бостон-терьер          Черно-белый           25
# 15     Чарли             Шиба-ину          Трехцветный           30
# 17     Белль        Френч бульдог                Белый           35
# 8      Тедди         Бассет-хаунд          Трехцветный           30
# 14    Оливер             Доберман  Черный и коричневый           45
# 18      Сади                Хаски           Серо-белый           45
# 7       Лола               Шарпей           Коричневый           40
# 11    Джесси         Бордер-колли          Черно-белый           50
# 2       Макс             Далматин          Черно-белый           55
# 10    Бентли  Золотистый ретривер           Золотистый           60
# 1       Рекс              Бульдог              Палевый           40
# 5       Мило             Лабрадор          Абрикосовый           58
# 0       Сноу             Лабрадор           Шоколадный           60
# 19     Сэнди                Акита           Коричневый           60
# 12     Чарли               Боксер             Тигровый           55
# 13  Максимус            Ротвейлер       Черный и рыжий           70
#
#     Weight (kg) Date of Birth
# 4             3    2020-09-30
# 6             3    2019-08-12
# 9             4    2017-09-28
# 3             5    2019-04-15
# 16            5    2020-03-08
# 15            6    2018-11-17
# 17            8    2019-10-12
# 8            10    2020-05-19
# 14           12    2016-12-30
# 18           12    2016-06-23
# 7            15    2018-01-03
# 11           18    2019-02-08
# 2            20    2017-11-20
# 10           25    2016-07-14
# 1            25    2018-06-05
# 5            27    2016-03-25
# 0            30    2015-02-10
# 19           30    2015-08-02
# 12           30    2017-04-22
# 13           40    2015-09-07

# %%
dogs["Name"]
# Out:
# 0         Сноу
# 1         Рекс
# 2         Макс
# 3         Луна
# 4         Джек
# 5         Мило
# 6        Бэйли
# 7         Лола
# 8        Тедди
# 9         Макс
# 10      Бентли
# 11      Джесси
# 12       Чарли
# 13    Максимус
# 14      Оливер
# 15       Чарли
# 16         Луи
# 17       Белль
# 18        Сади
# 19       Сэнди
# Name: Name, dtype: object

# %%
dogs[["Name", "Height (cm)"]]
# Out:
#         Name  Height (cm)
# 0       Сноу           60
# 1       Рекс           40
# 2       Макс           55
# 3       Луна           25
# 4       Джек           20
# 5       Мило           58
# 6      Бэйли           20
# 7       Лола           40
# 8      Тедди           30
# 9       Макс           25
# 10    Бентли           60
# 11    Джесси           50
# 12     Чарли           55
# 13  Максимус           70
# 14    Оливер           45
# 15     Чарли           30
# 16       Луи           25
# 17     Белль           35
# 18      Сади           45
# 19     Сэнди           60

# %%
dogs[dogs["Height (cm)"] > 50]
# Out:
#         Name                Breed           Color  Height (cm)  Weight (kg)  \
# 0       Сноу             Лабрадор      Шоколадный           60           30
# 2       Макс             Далматин     Черно-белый           55           20
# 5       Мило             Лабрадор     Абрикосовый           58           27
# 10    Бентли  Золотистый ретривер      Золотистый           60           25
# 12     Чарли               Боксер        Тигровый           55           30
# 13  Максимус            Ротвейлер  Черный и рыжий           70           40
# 19     Сэнди                Акита      Коричневый           60           30
#
#    Date of Birth
# 0     2015-02-10
# 2     2017-11-20
# 5     2016-03-25
# 10    2016-07-14
# 12    2017-04-22
# 13    2015-09-07
# 19    2015-08-02

# %%
dogs[dogs["Breed"] == "Лабрадор"]
# Out:
#    Name     Breed        Color  Height (cm)  Weight (kg) Date of Birth
# 0  Сноу  Лабрадор   Шоколадный           60           30    2015-02-10
# 5  Мило  Лабрадор  Абрикосовый           58           27    2016-03-25

# %%
dogs[dogs["Date of Birth"] > "2019-01-01"]
# Out:
#       Name               Breed        Color  Height (cm)  Weight (kg)  \
# 3     Луна              Ши-тцу        Белый           25            5
# 4     Джек  Йоркширский терьер        Серый           20            3
# 6    Бэйли            Чихуахуа       Черный           20            3
# 8    Тедди        Бассет-хаунд  Трехцветный           30           10
# 11  Джесси        Бордер-колли  Черно-белый           50           18
# 16     Луи       Бостон-терьер  Черно-белый           25            5
# 17   Белль       Френч бульдог        Белый           35            8
#
#    Date of Birth
# 3     2019-04-15
# 4     2020-09-30
# 6     2019-08-12
# 8     2020-05-19
# 11    2019-02-08
# 16    2020-03-08
# 17    2019-10-12

# %%
is_small = dogs["Height (cm)"] < 40
is_black = dogs["Color"] == "Черный"
dogs[is_small | is_black]
# Out:
#      Name               Breed        Color  Height (cm)  Weight (kg)  \
# 3    Луна              Ши-тцу        Белый           25            5
# 4    Джек  Йоркширский терьер        Серый           20            3
# 6   Бэйли            Чихуахуа       Черный           20            3
# 8   Тедди        Бассет-хаунд  Трехцветный           30           10
# 9    Макс         Померанский    Оранжевый           25            4
# 15  Чарли            Шиба-ину  Трехцветный           30            6
# 16    Луи       Бостон-терьер  Черно-белый           25            5
# 17  Белль       Френч бульдог        Белый           35            8
#
#    Date of Birth
# 3     2019-04-15
# 4     2020-09-30
# 6     2019-08-12
# 8     2020-05-19
# 9     2017-09-28
# 15    2018-11-17
# 16    2020-03-08
# 17    2019-10-12

# %%
is_black_or_white = dogs["Color"].isin(["Черный", "Белый"])
dogs[is_black_or_white]
# Out:
#      Name          Breed   Color  Height (cm)  Weight (kg) Date of Birth
# 3    Луна         Ши-тцу   Белый           25            5    2019-04-15
# 6   Бэйли       Чихуахуа  Черный           20            3    2019-08-12
# 17  Белль  Френч бульдог   Белый           35            8    2019-10-12

# %% [markdown]
# ### Создание новых столбцов

# %%
dogs["Height (m)"] = dogs["Height (cm)"]/ 100
dogs.head(5)
# Out:
#    Name               Breed        Color  Height (cm)  Weight (kg)  \
# 0  Сноу            Лабрадор   Шоколадный           60           30
# 1  Рекс             Бульдог      Палевый           40           25
# 2  Макс            Далматин  Черно-белый           55           20
# 3  Луна              Ши-тцу        Белый           25            5
# 4  Джек  Йоркширский терьер        Серый           20            3
#
#   Date of Birth  Height (m)
# 0    2015-02-10        0.60
# 1    2018-06-05        0.40
# 2    2017-11-20        0.55
# 3    2019-04-15        0.25
# 4    2020-09-30        0.20

# %%
dogs.shape
# Out:
# (20, 7)

# %%
dogs["BMI"] = dogs["Weight (kg)"] / dogs["Height (m)"] ** 2
dogs.head(5)
# Out:
#    Name               Breed        Color  Height (cm)  Weight (kg)  \
# 0  Сноу            Лабрадор   Шоколадный           60           30
# 1  Рекс             Бульдог      Палевый           40           25
# 2  Макс            Далматин  Черно-белый           55           20
# 3  Луна              Ши-тцу        Белый           25            5
# 4  Джек  Йоркширский терьер        Серый           20            3
#
#   Date of Birth  Height (m)         BMI
# 0    2015-02-10        0.60   83.333333
# 1    2018-06-05        0.40  156.250000
# 2    2017-11-20        0.55   66.115702
# 3    2019-04-15        0.25   80.000000
# 4    2020-09-30        0.20   75.000000

# %% [markdown]
# ### Сводная статистика

# %%
dogs.describe()
# Out:
#        Height (cm)  Weight (kg)  Height (m)         BMI
# count    20.000000    20.000000   20.000000   20.000000
# mean     42.400000    16.400000    0.424000   81.044852
# std      15.574608    11.287627    0.155746   22.088353
# min      20.000000     3.000000    0.200000   59.259259
# 25%      28.750000     5.750000    0.287500   66.528926
# 50%      42.500000    13.500000    0.425000   77.500000
# 75%      55.750000    25.500000    0.557500   83.333333
# max      70.000000    40.000000    0.700000  156.250000

# %%
dogs["Height (cm)"].mean()
# Out:
# 42.4

# %%
dogs["Height (cm)"].median()
# Out:
# 42.5

# %%
dogs["Height (cm)"].mode()
# Out:
# 0    25
# 1    60
# dtype: int64

# %%
dogs["Height (cm)"].min()
# Out:
# 20

# %%
dogs["Height (cm)"].max()
# Out:
# 70

# %%
dogs["Height (cm)"].var()
# Out:
# 242.56842105263163

# %%
dogs["Height (cm)"].std()
# Out:
# 15.574608215060552

# %%
dogs["Height (cm)"].sum()
# Out:
# 848

# %%
dogs["Height (cm)"].quantile(0.51)
# Out:
# 43.449999999999996

# %%
dogs["Date of Birth"].max()
# Out:
# '2020-09-30'

# %%
dogs["Date of Birth"].min()
# Out:
# '2015-02-10'

# %%
def pct30(column):
    return column.quantile(0.3)

dogs["Weight (kg)"].agg(pct30)
# Out:
# 7.4

# %%
dogs[["Weight (kg)", "Height (cm)"]].agg(pct30)
# Out:
# Weight (kg)     7.4
# Height (cm)    30.0
# dtype: float64

# %%
def pct40(column):
    return column.quantile(0.4)

dogs[["Weight (kg)", "Height (cm)"]].agg([pct30, pct40])
# Out:
#        Weight (kg)  Height (cm)
# pct30          7.4         30.0
# pct40         11.2         38.0

# %%
dogs["Weight (kg)"].cumsum()
# Out:
# 0      30
# 1      55
# 2      75
# 3      80
# 4      83
# 5     110
# 6     113
# 7     128
# 8     138
# 9     142
# 10    167
# 11    185
# 12    215
# 13    255
# 14    267
# 15    273
# 16    278
# 17    286
# 18    298
# 19    328
# Name: Weight (kg), dtype: int64

# %% [markdown]
# ### Создание датасета посещение вет лечебницы

# %%
# Создаем DataFrame

# Добавляем дату посещения (случайные даты) и вес собаки (случайные значения)
import random
import datetime

# Генерируем дополнительные записи (в данном случае, добавим 55 дополнительных записей)
vet_visits = {
    'Name': [random.choice(data['Name']) for _ in range(75)],
    'Breed': [random.choice(data['Breed']) for _ in range(75)],
    'Color': [random.choice(data['Color']) for _ in range(75)],
    'Height (cm)': [random.randint(20, 70) for _ in range(75)],
    'Weight (kg)': [random.randint(3, 40) for _ in range(75)],
    'Date of Birth': [f"{random.randint(2015, 2022)}-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}" for _ in range(75)],
    'Visit Date': [datetime.date(2023, random.randint(1, 9), random.randint(1, 28)) for _ in range(75)]
}


vet_visits = pd.DataFrame(vet_visits)

vet_visits = vet_visits[["Visit Date", "Name", "Breed", "Weight (kg)"]]

print(vet_visits)
# Out:
#     Visit Date      Name          Breed  Weight (kg)
# 0   2023-04-10      Джек         Шарпей           27
# 1   2023-05-23     Тедди          Акита           28
# 2   2023-01-15    Бентли          Хаски           13
# 3   2023-05-21      Сади  Бостон-терьер           33
# 4   2023-09-15  Максимус       Лабрадор           22
# ..         ...       ...            ...          ...
# 70  2023-07-19      Рекс       Лабрадор           28
# 71  2023-06-20     Бэйли         Шарпей           38
# 72  2023-02-06      Мило         Шарпей           35
# 73  2023-08-02     Чарли       Далматин            5
# 74  2023-07-03      Рекс          Хаски           30
#
# [75 rows x 4 columns]

# %%
vet_visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Visit Date   75 non-null     object
#  1   Name         75 non-null     object
#  2   Breed        75 non-null     object
#  3   Weight (kg)  75 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.5+ KB

# %%
vet_visits.drop_duplicates(subset="Name")
# Out:
#     Visit Date      Name                Breed  Weight (kg)
# 0   2023-04-10      Джек               Шарпей           27
# 1   2023-05-23     Тедди                Акита           28
# 2   2023-01-15    Бентли                Хаски           13
# 3   2023-05-21      Сади        Бостон-терьер           33
# 4   2023-09-15  Максимус             Лабрадор           22
# 5   2023-05-26     Бэйли  Золотистый ретривер           14
# 6   2023-08-24      Сноу             Чихуахуа           17
# 7   2023-05-16      Мило              Бульдог           20
# 11  2023-07-13     Чарли               Шарпей            9
# 13  2023-09-07     Сэнди         Бордер-колли           31
# 14  2023-01-17      Макс               Ши-тцу            5
# 16  2023-04-16      Лола               Ши-тцу           17
# 19  2023-01-07    Оливер            Ротвейлер            4
# 25  2023-08-19     Белль             Лабрадор           17
# 35  2023-06-15      Рекс   Йоркширский терьер           12
# 42  2023-06-19       Луи          Померанский           26
# 48  2023-04-23    Джесси               Шарпей           33

# %%
unique_dogs = vet_visits.drop_duplicates(subset=["Name", "Breed"])
unique_dogs
# Out:
#     Visit Date      Name          Breed  Weight (kg)
# 0   2023-04-10      Джек         Шарпей           27
# 1   2023-05-23     Тедди          Акита           28
# 2   2023-01-15    Бентли          Хаски           13
# 3   2023-05-21      Сади  Бостон-терьер           33
# 4   2023-09-15  Максимус       Лабрадор           22
# ..         ...       ...            ...          ...
# 68  2023-09-16    Джесси       Лабрадор            9
# 69  2023-09-27     Чарли          Хаски           29
# 70  2023-07-19      Рекс       Лабрадор           28
# 71  2023-06-20     Бэйли         Шарпей           38
# 72  2023-02-06      Мило         Шарпей           35
#
# [71 rows x 4 columns]

# %%
unique_dogs["Breed"].value_counts()
# Out:
# Лабрадор               8
# Шарпей                 7
# Хаски                  6
# Бассет-хаунд           5
# Ротвейлер              5
# Померанский            4
# Золотистый ретривер    4
# Йоркширский терьер     4
# Доберман               3
# Френч бульдог          3
# Шиба-ину               3
# Ши-тцу                 3
# Бульдог                3
# Чихуахуа               3
# Акита                  2
# Далматин               2
# Боксер                 2
# Бостон-терьер          2
# Бордер-колли           2
# Name: Breed, dtype: int64

# %%
unique_dogs["Breed"].value_counts(normalize=True).sort_index()
# Out:
# Акита                  0.028169
# Бассет-хаунд           0.070423
# Боксер                 0.028169
# Бордер-колли           0.028169
# Бостон-терьер          0.028169
# Бульдог                0.042254
# Далматин               0.028169
# Доберман               0.042254
# Золотистый ретривер    0.056338
# Йоркширский терьер     0.056338
# Лабрадор               0.112676
# Померанский            0.056338
# Ротвейлер              0.070423
# Френч бульдог          0.042254
# Хаски                  0.084507
# Чихуахуа               0.042254
# Шарпей                 0.098592
# Ши-тцу                 0.042254
# Шиба-ину               0.042254
# Name: Breed, dtype: float64

# %% [markdown]
# ### Сводная статистика сгруппированных данных

# %%
dogs[dogs["Color"] == "Шоколадный"]["Weight (kg)"].mean()
# Out:
# 30.0

# %%
dogs[dogs["Color"] == "Черно-белый"]["Weight (kg)"].mean()
# Out:
# 14.333333333333334

# %%
dogs[dogs["Color"] == "Белый"]["Weight (kg)"].mean()
# Out:
# 6.5

# %%
dogs.groupby("Color")["Weight (kg)"].mean()
# Out:
# Color
# Абрикосовый            27.000000
# Белый                   6.500000
# Золотистый             25.000000
# Коричневый             22.500000
# Оранжевый               4.000000
# Палевый                25.000000
# Серо-белый             12.000000
# Серый                   3.000000
# Тигровый               30.000000
# Трехцветный             8.000000
# Черно-белый            14.333333
# Черный                  3.000000
# Черный и коричневый    12.000000
# Черный и рыжий         40.000000
# Шоколадный             30.000000
# Name: Weight (kg), dtype: float64

# %%
dogs.groupby("Color")["Weight (kg)"].agg([min, max, sum])
# Out:
#                      min  max  sum
# Color
# Абрикосовый           27   27   27
# Белый                  5    8   13
# Золотистый            25   25   25
# Коричневый            15   30   45
# Оранжевый              4    4    4
# Палевый               25   25   25
# Серо-белый            12   12   12
# Серый                  3    3    3
# Тигровый              30   30   30
# Трехцветный            6   10   16
# Черно-белый            5   20   43
# Черный                 3    3    3
# Черный и коричневый   12   12   12
# Черный и рыжий        40   40   40
# Шоколадный            30   30   30

# %%
dogs.groupby(["Color", "Breed"])["Weight (kg)"].mean()
# Out:
# Color                Breed
# Абрикосовый          Лабрадор               27.0
# Белый                Френч бульдог           8.0
#                      Ши-тцу                  5.0
# Золотистый           Золотистый ретривер    25.0
# Коричневый           Акита                  30.0
#                      Шарпей                 15.0
# Оранжевый            Померанский             4.0
# Палевый              Бульдог                25.0
# Серо-белый           Хаски                  12.0
# Серый                Йоркширский терьер      3.0
# Тигровый             Боксер                 30.0
# Трехцветный          Бассет-хаунд           10.0
#                      Шиба-ину                6.0
# Черно-белый          Бордер-колли           18.0
#                      Бостон-терьер           5.0
#                      Далматин               20.0
# Черный               Чихуахуа                3.0
# Черный и коричневый  Доберман               12.0
# Черный и рыжий       Ротвейлер              40.0
# Шоколадный           Лабрадор               30.0
# Name: Weight (kg), dtype: float64

# %%
dogs.groupby(["Color", "Breed"])[["Weight (kg)", "Height (cm)"]].mean()
# Out:
#                                          Weight (kg)  Height (cm)
# Color               Breed
# Абрикосовый         Лабрадор                    27.0         58.0
# Белый               Френч бульдог                8.0         35.0
#                     Ши-тцу                       5.0         25.0
# Золотистый          Золотистый ретривер         25.0         60.0
# Коричневый          Акита                       30.0         60.0
#                     Шарпей                      15.0         40.0
# Оранжевый           Померанский                  4.0         25.0
# Палевый             Бульдог                     25.0         40.0
# Серо-белый          Хаски                       12.0         45.0
# Серый               Йоркширский терьер           3.0         20.0
# Тигровый            Боксер                      30.0         55.0
# Трехцветный         Бассет-хаунд                10.0         30.0
#                     Шиба-ину                     6.0         30.0
# Черно-белый         Бордер-колли                18.0         50.0
#                     Бостон-терьер                5.0         25.0
#                     Далматин                    20.0         55.0
# Черный              Чихуахуа                     3.0         20.0
# Черный и коричневый Доберман                    12.0         45.0
# Черный и рыжий      Ротвейлер                   40.0         70.0
# Шоколадный          Лабрадор                    30.0         60.0

# %%
dogs.pivot_table(values="Weight (kg)", index="Color")
# Out:
#                      Weight (kg)
# Color
# Абрикосовый            27.000000
# Белый                   6.500000
# Золотистый             25.000000
# Коричневый             22.500000
# Оранжевый               4.000000
# Палевый                25.000000
# Серо-белый             12.000000
# Серый                   3.000000
# Тигровый               30.000000
# Трехцветный             8.000000
# Черно-белый            14.333333
# Черный                  3.000000
# Черный и коричневый    12.000000
# Черный и рыжий         40.000000
# Шоколадный             30.000000

# %%
import numpy as np
dogs.pivot_table(values="Weight (kg)", index="Color", aggfunc=np.median)
# Out:
#                      Weight (kg)
# Color
# Абрикосовый                 27.0
# Белый                        6.5
# Золотистый                  25.0
# Коричневый                  22.5
# Оранжевый                    4.0
# Палевый                     25.0
# Серо-белый                  12.0
# Серый                        3.0
# Тигровый                    30.0
# Трехцветный                  8.0
# Черно-белый                 18.0
# Черный                       3.0
# Черный и коричневый         12.0
# Черный и рыжий              40.0
# Шоколадный                  30.0

# %%
dogs.pivot_table(values="Weight (kg)", index="Color", aggfunc=[np.median, np.mean])
# Out:
#                          median        mean
#                     Weight (kg) Weight (kg)
# Color
# Абрикосовый                27.0   27.000000
# Белый                       6.5    6.500000
# Золотистый                 25.0   25.000000
# Коричневый                 22.5   22.500000
# Оранжевый                   4.0    4.000000
# Палевый                    25.0   25.000000
# Серо-белый                 12.0   12.000000
# Серый                       3.0    3.000000
# Тигровый                   30.0   30.000000
# Трехцветный                 8.0    8.000000
# Черно-белый                18.0   14.333333
# Черный                      3.0    3.000000
# Черный и коричневый        12.0   12.000000
# Черный и рыжий             40.0   40.000000
# Шоколадный                 30.0   30.000000

# %%
dogs.pivot_table(values="Weight (kg)", index="Color", columns="Breed")
# Out:
# Breed                Акита  Бассет-хаунд  Боксер  Бордер-колли  Бостон-терьер  \
# Color
# Абрикосовый            NaN           NaN     NaN           NaN            NaN
# Белый                  NaN           NaN     NaN           NaN            NaN
# Золотистый             NaN           NaN     NaN           NaN            NaN
# Коричневый            30.0           NaN     NaN           NaN            NaN
# Оранжевый              NaN           NaN     NaN           NaN            NaN
# Палевый                NaN           NaN     NaN           NaN            NaN
# Серо-белый             NaN           NaN     NaN           NaN            NaN
# Серый                  NaN           NaN     NaN           NaN            NaN
# Тигровый               NaN           NaN    30.0           NaN            NaN
# Трехцветный            NaN          10.0     NaN           NaN            NaN
# Черно-белый            NaN           NaN     NaN          18.0            5.0
# Черный                 NaN           NaN     NaN           NaN            NaN
# Черный и коричневый    NaN           NaN     NaN           NaN            NaN
# Черный и рыжий         NaN           NaN     NaN           NaN            NaN
# Шоколадный             NaN           NaN     NaN           NaN            NaN
#
# Breed                Бульдог  Далматин  Доберман  Золотистый ретривер  \
# Color
# Абрикосовый              NaN       NaN       NaN                  NaN
# Белый                    NaN       NaN       NaN                  NaN
# Золотистый               NaN       NaN       NaN                 25.0
# Коричневый               NaN       NaN       NaN                  NaN
# Оранжевый                NaN       NaN       NaN                  NaN
# Палевый                 25.0       NaN       NaN                  NaN
# Серо-белый               NaN       NaN       NaN                  NaN
# Серый                    NaN       NaN       NaN                  NaN
# Тигровый                 NaN       NaN       NaN                  NaN
# Трехцветный              NaN       NaN       NaN                  NaN
# Черно-белый              NaN      20.0       NaN                  NaN
# Черный                   NaN       NaN       NaN                  NaN
# Черный и коричневый      NaN       NaN      12.0                  NaN
# Черный и рыжий           NaN       NaN       NaN                  NaN
# Шоколадный               NaN       NaN       NaN                  NaN
#
# Breed                Йоркширский терьер  Лабрадор  Померанский  Ротвейлер  \
# Color
# Абрикосовый                         NaN      27.0          NaN        NaN
# Белый                               NaN       NaN          NaN        NaN
# Золотистый                          NaN       NaN          NaN        NaN
# Коричневый                          NaN       NaN          NaN        NaN
# Оранжевый                           NaN       NaN          4.0        NaN
# Палевый                             NaN       NaN          NaN        NaN
# Серо-белый                          NaN       NaN          NaN        NaN
# Серый                               3.0       NaN          NaN        NaN
# Тигровый                            NaN       NaN          NaN        NaN
# Трехцветный                         NaN       NaN          NaN        NaN
# Черно-белый                         NaN       NaN          NaN        NaN
# Черный                              NaN       NaN          NaN        NaN
# Черный и коричневый                 NaN       NaN          NaN        NaN
# Черный и рыжий                      NaN       NaN          NaN       40.0
# Шоколадный                          NaN      30.0          NaN        NaN
#
# Breed                Френч бульдог  Хаски  Чихуахуа  Шарпей  Ши-тцу  Шиба-ину
# Color
# Абрикосовый                    NaN    NaN       NaN     NaN     NaN       NaN
# Белый                          8.0    NaN       NaN     NaN     5.0       NaN
# Золотистый                     NaN    NaN       NaN     NaN     NaN       NaN
# Коричневый                     NaN    NaN       NaN    15.0     NaN       NaN
# Оранжевый                      NaN    NaN       NaN     NaN     NaN       NaN
# Палевый                        NaN    NaN       NaN     NaN     NaN       NaN
# Серо-белый                     NaN   12.0       NaN     NaN     NaN       NaN
# Серый                          NaN    NaN       NaN     NaN     NaN       NaN
# Тигровый                       NaN    NaN       NaN     NaN     NaN       NaN
# Трехцветный                    NaN    NaN       NaN     NaN     NaN       6.0
# Черно-белый                    NaN    NaN       NaN     NaN     NaN       NaN
# Черный                         NaN    NaN       3.0     NaN     NaN       NaN
# Черный и коричневый            NaN    NaN       NaN     NaN     NaN       NaN
# Черный и рыжий                 NaN    NaN       NaN     NaN     NaN       NaN
# Шоколадный                     NaN    NaN       NaN     NaN     NaN       NaN

# %%
dogs.pivot_table(values="Weight (kg)", index="Color", columns="Breed", fill_value=0)
# Out:
# Breed                Акита  Бассет-хаунд  Боксер  Бордер-колли  Бостон-терьер  \
# Color
# Абрикосовый              0             0       0             0              0
# Белый                    0             0       0             0              0
# Золотистый               0             0       0             0              0
# Коричневый              30             0       0             0              0
# Оранжевый                0             0       0             0              0
# Палевый                  0             0       0             0              0
# Серо-белый               0             0       0             0              0
# Серый                    0             0       0             0              0
# Тигровый                 0             0      30             0              0
# Трехцветный              0            10       0             0              0
# Черно-белый              0             0       0            18              5
# Черный                   0             0       0             0              0
# Черный и коричневый      0             0       0             0              0
# Черный и рыжий           0             0       0             0              0
# Шоколадный               0             0       0             0              0
#
# Breed                Бульдог  Далматин  Доберман  Золотистый ретривер  \
# Color
# Абрикосовый                0         0         0                    0
# Белый                      0         0         0                    0
# Золотистый                 0         0         0                   25
# Коричневый                 0         0         0                    0
# Оранжевый                  0         0         0                    0
# Палевый                   25         0         0                    0
# Серо-белый                 0         0         0                    0
# Серый                      0         0         0                    0
# Тигровый                   0         0         0                    0
# Трехцветный                0         0         0                    0
# Черно-белый                0        20         0                    0
# Черный                     0         0         0                    0
# Черный и коричневый        0         0        12                    0
# Черный и рыжий             0         0         0                    0
# Шоколадный                 0         0         0                    0
#
# Breed                Йоркширский терьер  Лабрадор  Померанский  Ротвейлер  \
# Color
# Абрикосовый                           0        27            0          0
# Белый                                 0         0            0          0
# Золотистый                            0         0            0          0
# Коричневый                            0         0            0          0
# Оранжевый                             0         0            4          0
# Палевый                               0         0            0          0
# Серо-белый                            0         0            0          0
# Серый                                 3         0            0          0
# Тигровый                              0         0            0          0
# Трехцветный                           0         0            0          0
# Черно-белый                           0         0            0          0
# Черный                                0         0            0          0
# Черный и коричневый                   0         0            0          0
# Черный и рыжий                        0         0            0         40
# Шоколадный                            0        30            0          0
#
# Breed                Френч бульдог  Хаски  Чихуахуа  Шарпей  Ши-тцу  Шиба-ину
# Color
# Абрикосовый                      0      0         0       0       0         0
# Белый                            8      0         0       0       5         0
# Золотистый                       0      0         0       0       0         0
# Коричневый                       0      0         0      15       0         0
# Оранжевый                        0      0         0       0       0         0
# Палевый                          0      0         0       0       0         0
# Серо-белый                       0     12         0       0       0         0
# Серый                            0      0         0       0       0         0
# Тигровый                         0      0         0       0       0         0
# Трехцветный                      0      0         0       0       0         6
# Черно-белый                      0      0         0       0       0         0
# Черный                           0      0         3       0       0         0
# Черный и коричневый              0      0         0       0       0         0
# Черный и рыжий                   0      0         0       0       0         0
# Шоколадный                       0      0         0       0       0         0

# %%
dogs.pivot_table(values="Weight (kg)", index="Color", columns="Breed", fill_value=0, margins=True)
# Out:
# Breed                Акита  Бассет-хаунд  Боксер  Бордер-колли  Бостон-терьер  \
# Color
# Абрикосовый              0             0       0             0              0
# Белый                    0             0       0             0              0
# Золотистый               0             0       0             0              0
# Коричневый              30             0       0             0              0
# Оранжевый                0             0       0             0              0
# Палевый                  0             0       0             0              0
# Серо-белый               0             0       0             0              0
# Серый                    0             0       0             0              0
# Тигровый                 0             0      30             0              0
# Трехцветный              0            10       0             0              0
# Черно-белый              0             0       0            18              5
# Черный                   0             0       0             0              0
# Черный и коричневый      0             0       0             0              0
# Черный и рыжий           0             0       0             0              0
# Шоколадный               0             0       0             0              0
# All                     30            10      30            18              5
#
# Breed                Бульдог  Далматин  Доберман  Золотистый ретривер  \
# Color
# Абрикосовый                0         0         0                    0
# Белый                      0         0         0                    0
# Золотистый                 0         0         0                   25
# Коричневый                 0         0         0                    0
# Оранжевый                  0         0         0                    0
# Палевый                   25         0         0                    0
# Серо-белый                 0         0         0                    0
# Серый                      0         0         0                    0
# Тигровый                   0         0         0                    0
# Трехцветный                0         0         0                    0
# Черно-белый                0        20         0                    0
# Черный                     0         0         0                    0
# Черный и коричневый        0         0        12                    0
# Черный и рыжий             0         0         0                    0
# Шоколадный                 0         0         0                    0
# All                       25        20        12                   25
#
# Breed                Йоркширский терьер  Лабрадор  Померанский  Ротвейлер  \
# Color
# Абрикосовый                           0      27.0            0          0
# Белый                                 0       0.0            0          0
# Золотистый                            0       0.0            0          0
# Коричневый                            0       0.0            0          0
# Оранжевый                             0       0.0            4          0
# Палевый                               0       0.0            0          0
# Серо-белый                            0       0.0            0          0
# Серый                                 3       0.0            0          0
# Тигровый                              0       0.0            0          0
# Трехцветный                           0       0.0            0          0
# Черно-белый                           0       0.0            0          0
# Черный                                0       0.0            0          0
# Черный и коричневый                   0       0.0            0          0
# Черный и рыжий                        0       0.0            0         40
# Шоколадный                            0      30.0            0          0
# All                                   3      28.5            4         40
#
# Breed                Френч бульдог  Хаски  Чихуахуа  Шарпей  Ши-тцу  Шиба-ину  \
# Color
# Абрикосовый                      0      0         0       0       0         0
# Белый                            8      0         0       0       5         0
# Золотистый                       0      0         0       0       0         0
# Коричневый                       0      0         0      15       0         0
# Оранжевый                        0      0         0       0       0         0
# Палевый                          0      0         0       0       0         0
# Серо-белый                       0     12         0       0       0         0
# Серый                            0      0         0       0       0         0
# Тигровый                         0      0         0       0       0         0
# Трехцветный                      0      0         0       0       0         6
# Черно-белый                      0      0         0       0       0         0
# Черный                           0      0         3       0       0         0
# Черный и коричневый              0      0         0       0       0         0
# Черный и рыжий                   0      0         0       0       0         0
# Шоколадный                       0      0         0       0       0         0
# All                              8     12         3      15       5         6
#
# Breed                      All
# Color
# Абрикосовый          27.000000
# Белый                 6.500000
# Золотистый           25.000000
# Коричневый           22.500000
# Оранжевый             4.000000
# Палевый              25.000000
# Серо-белый           12.000000
# Серый                 3.000000
# Тигровый             30.000000
# Трехцветный           8.000000
# Черно-белый          14.333333
# Черный                3.000000
# Черный и коричневый  12.000000
# Черный и рыжий       40.000000
# Шоколадный           30.000000
# All                  16.400000

# %% [markdown]
# ### Явные индексы

# %%
dogs_ind = dogs.set_index("Name")
dogs_ind
# Out:
#                         Breed                Color  Height (cm)  Weight (kg)  \
# Name
# Сноу                 Лабрадор           Шоколадный           60           30
# Рекс                  Бульдог              Палевый           40           25
# Макс                 Далматин          Черно-белый           55           20
# Луна                   Ши-тцу                Белый           25            5
# Джек       Йоркширский терьер                Серый           20            3
# Мило                 Лабрадор          Абрикосовый           58           27
# Бэйли                Чихуахуа               Черный           20            3
# Лола                   Шарпей           Коричневый           40           15
# Тедди            Бассет-хаунд          Трехцветный           30           10
# Макс              Померанский            Оранжевый           25            4
# Бентли    Золотистый ретривер           Золотистый           60           25
# Джесси           Бордер-колли          Черно-белый           50           18
# Чарли                  Боксер             Тигровый           55           30
# Максимус            Ротвейлер       Черный и рыжий           70           40
# Оливер               Доберман  Черный и коричневый           45           12
# Чарли                Шиба-ину          Трехцветный           30            6
# Луи             Бостон-терьер          Черно-белый           25            5
# Белль           Френч бульдог                Белый           35            8
# Сади                    Хаски           Серо-белый           45           12
# Сэнди                   Акита           Коричневый           60           30
#
#          Date of Birth  Height (m)         BMI
# Name
# Сноу        2015-02-10        0.60   83.333333
# Рекс        2018-06-05        0.40  156.250000
# Макс        2017-11-20        0.55   66.115702
# Луна        2019-04-15        0.25   80.000000
# Джек        2020-09-30        0.20   75.000000
# Мило        2016-03-25        0.58   80.261593
# Бэйли       2019-08-12        0.20   75.000000
# Лола        2018-01-03        0.40   93.750000
# Тедди       2020-05-19        0.30  111.111111
# Макс        2017-09-28        0.25   64.000000
# Бентли      2016-07-14        0.60   69.444444
# Джесси      2019-02-08        0.50   72.000000
# Чарли       2017-04-22        0.55   99.173554
# Максимус    2015-09-07        0.70   81.632653
# Оливер      2016-12-30        0.45   59.259259
# Чарли       2018-11-17        0.30   66.666667
# Луи         2020-03-08        0.25   80.000000
# Белль       2019-10-12        0.35   65.306122
# Сади        2016-06-23        0.45   59.259259
# Сэнди       2015-08-02        0.60   83.333333

# %%
dogs_ind.reset_index()
# Out:
#         Name                Breed                Color  Height (cm)  \
# 0       Сноу             Лабрадор           Шоколадный           60
# 1       Рекс              Бульдог              Палевый           40
# 2       Макс             Далматин          Черно-белый           55
# 3       Луна               Ши-тцу                Белый           25
# 4       Джек   Йоркширский терьер                Серый           20
# 5       Мило             Лабрадор          Абрикосовый           58
# 6      Бэйли             Чихуахуа               Черный           20
# 7       Лола               Шарпей           Коричневый           40
# 8      Тедди         Бассет-хаунд          Трехцветный           30
# 9       Макс          Померанский            Оранжевый           25
# 10    Бентли  Золотистый ретривер           Золотистый           60
# 11    Джесси         Бордер-колли          Черно-белый           50
# 12     Чарли               Боксер             Тигровый           55
# 13  Максимус            Ротвейлер       Черный и рыжий           70
# 14    Оливер             Доберман  Черный и коричневый           45
# 15     Чарли             Шиба-ину          Трехцветный           30
# 16       Луи        Бостон-терьер          Черно-белый           25
# 17     Белль        Френч бульдог                Белый           35
# 18      Сади                Хаски           Серо-белый           45
# 19     Сэнди                Акита           Коричневый           60
#
#     Weight (kg) Date of Birth  Height (m)         BMI
# 0            30    2015-02-10        0.60   83.333333
# 1            25    2018-06-05        0.40  156.250000
# 2            20    2017-11-20        0.55   66.115702
# 3             5    2019-04-15        0.25   80.000000
# 4             3    2020-09-30        0.20   75.000000
# 5            27    2016-03-25        0.58   80.261593
# 6             3    2019-08-12        0.20   75.000000
# 7            15    2018-01-03        0.40   93.750000
# 8            10    2020-05-19        0.30  111.111111
# 9             4    2017-09-28        0.25   64.000000
# 10           25    2016-07-14        0.60   69.444444
# 11           18    2019-02-08        0.50   72.000000
# 12           30    2017-04-22        0.55   99.173554
# 13           40    2015-09-07        0.70   81.632653
# 14           12    2016-12-30        0.45   59.259259
# 15            6    2018-11-17        0.30   66.666667
# 16            5    2020-03-08        0.25   80.000000
# 17            8    2019-10-12        0.35   65.306122
# 18           12    2016-06-23        0.45   59.259259
# 19           30    2015-08-02        0.60   83.333333

# %%
dogs_ind.reset_index(drop=True)
# Out:
#                   Breed                Color  Height (cm)  Weight (kg)  \
# 0              Лабрадор           Шоколадный           60           30
# 1               Бульдог              Палевый           40           25
# 2              Далматин          Черно-белый           55           20
# 3                Ши-тцу                Белый           25            5
# 4    Йоркширский терьер                Серый           20            3
# 5              Лабрадор          Абрикосовый           58           27
# 6              Чихуахуа               Черный           20            3
# 7                Шарпей           Коричневый           40           15
# 8          Бассет-хаунд          Трехцветный           30           10
# 9           Померанский            Оранжевый           25            4
# 10  Золотистый ретривер           Золотистый           60           25
# 11         Бордер-колли          Черно-белый           50           18
# 12               Боксер             Тигровый           55           30
# 13            Ротвейлер       Черный и рыжий           70           40
# 14             Доберман  Черный и коричневый           45           12
# 15             Шиба-ину          Трехцветный           30            6
# 16        Бостон-терьер          Черно-белый           25            5
# 17        Френч бульдог                Белый           35            8
# 18                Хаски           Серо-белый           45           12
# 19                Акита           Коричневый           60           30
#
#    Date of Birth  Height (m)         BMI
# 0     2015-02-10        0.60   83.333333
# 1     2018-06-05        0.40  156.250000
# 2     2017-11-20        0.55   66.115702
# 3     2019-04-15        0.25   80.000000
# 4     2020-09-30        0.20   75.000000
# 5     2016-03-25        0.58   80.261593
# 6     2019-08-12        0.20   75.000000
# 7     2018-01-03        0.40   93.750000
# 8     2020-05-19        0.30  111.111111
# 9     2017-09-28        0.25   64.000000
# 10    2016-07-14        0.60   69.444444
# 11    2019-02-08        0.50   72.000000
# 12    2017-04-22        0.55   99.173554
# 13    2015-09-07        0.70   81.632653
# 14    2016-12-30        0.45   59.259259
# 15    2018-11-17        0.30   66.666667
# 16    2020-03-08        0.25   80.000000
# 17    2019-10-12        0.35   65.306122
# 18    2016-06-23        0.45   59.259259
# 19    2015-08-02        0.60   83.333333

# %%
dogs[dogs["Name"].isin(["Макс", "Луна"])]
# Out:
#    Name        Breed        Color  Height (cm)  Weight (kg) Date of Birth  \
# 2  Макс     Далматин  Черно-белый           55           20    2017-11-20
# 3  Луна       Ши-тцу        Белый           25            5    2019-04-15
# 9  Макс  Померанский    Оранжевый           25            4    2017-09-28
#
#    Height (m)        BMI
# 2        0.55  66.115702
# 3        0.25  80.000000
# 9        0.25  64.000000

# %%
dogs_ind.loc[["Макс", "Луна"]]
# Out:
#             Breed        Color  Height (cm)  Weight (kg) Date of Birth  \
# Name
# Макс     Далматин  Черно-белый           55           20    2017-11-20
# Макс  Померанский    Оранжевый           25            4    2017-09-28
# Луна       Ши-тцу        Белый           25            5    2019-04-15
#
#       Height (m)        BMI
# Name
# Макс        0.55  66.115702
# Макс        0.25  64.000000
# Луна        0.25  80.000000

# %%
dogs_ind2 = dogs.set_index("Breed")
dogs_ind2
# Out:
#                          Name                Color  Height (cm)  Weight (kg)  \
# Breed
# Лабрадор                 Сноу           Шоколадный           60           30
# Бульдог                  Рекс              Палевый           40           25
# Далматин                 Макс          Черно-белый           55           20
# Ши-тцу                   Луна                Белый           25            5
# Йоркширский терьер       Джек                Серый           20            3
# Лабрадор                 Мило          Абрикосовый           58           27
# Чихуахуа                Бэйли               Черный           20            3
# Шарпей                   Лола           Коричневый           40           15
# Бассет-хаунд            Тедди          Трехцветный           30           10
# Померанский              Макс            Оранжевый           25            4
# Золотистый ретривер    Бентли           Золотистый           60           25
# Бордер-колли           Джесси          Черно-белый           50           18
# Боксер                  Чарли             Тигровый           55           30
# Ротвейлер            Максимус       Черный и рыжий           70           40
# Доберман               Оливер  Черный и коричневый           45           12
# Шиба-ину                Чарли          Трехцветный           30            6
# Бостон-терьер             Луи          Черно-белый           25            5
# Френч бульдог           Белль                Белый           35            8
# Хаски                    Сади           Серо-белый           45           12
# Акита                   Сэнди           Коричневый           60           30
#
#                     Date of Birth  Height (m)         BMI
# Breed
# Лабрадор               2015-02-10        0.60   83.333333
# Бульдог                2018-06-05        0.40  156.250000
# Далматин               2017-11-20        0.55   66.115702
# Ши-тцу                 2019-04-15        0.25   80.000000
# Йоркширский терьер     2020-09-30        0.20   75.000000
# Лабрадор               2016-03-25        0.58   80.261593
# Чихуахуа               2019-08-12        0.20   75.000000
# Шарпей                 2018-01-03        0.40   93.750000
# Бассет-хаунд           2020-05-19        0.30  111.111111
# Померанский            2017-09-28        0.25   64.000000
# Золотистый ретривер    2016-07-14        0.60   69.444444
# Бордер-колли           2019-02-08        0.50   72.000000
# Боксер                 2017-04-22        0.55   99.173554
# Ротвейлер              2015-09-07        0.70   81.632653
# Доберман               2016-12-30        0.45   59.259259
# Шиба-ину               2018-11-17        0.30   66.666667
# Бостон-терьер          2020-03-08        0.25   80.000000
# Френч бульдог          2019-10-12        0.35   65.306122
# Хаски                  2016-06-23        0.45   59.259259
# Акита                  2015-08-02        0.60   83.333333

# %%
dogs_ind2.loc["Лабрадор"]
# Out:
#           Name        Color  Height (cm)  Weight (kg) Date of Birth  \
# Breed
# Лабрадор  Сноу   Шоколадный           60           30    2015-02-10
# Лабрадор  Мило  Абрикосовый           58           27    2016-03-25
#
#           Height (m)        BMI
# Breed
# Лабрадор        0.60  83.333333
# Лабрадор        0.58  80.261593

# %%
dogs_ind3 = dogs.set_index(["Breed", "Color"])
dogs_ind3
# Out:
#                                              Name  Height (cm)  Weight (kg)  \
# Breed               Color
# Лабрадор            Шоколадный               Сноу           60           30
# Бульдог             Палевый                  Рекс           40           25
# Далматин            Черно-белый              Макс           55           20
# Ши-тцу              Белый                    Луна           25            5
# Йоркширский терьер  Серый                    Джек           20            3
# Лабрадор            Абрикосовый              Мило           58           27
# Чихуахуа            Черный                  Бэйли           20            3
# Шарпей              Коричневый               Лола           40           15
# Бассет-хаунд        Трехцветный             Тедди           30           10
# Померанский         Оранжевый                Макс           25            4
# Золотистый ретривер Золотистый             Бентли           60           25
# Бордер-колли        Черно-белый            Джесси           50           18
# Боксер              Тигровый                Чарли           55           30
# Ротвейлер           Черный и рыжий       Максимус           70           40
# Доберман            Черный и коричневый    Оливер           45           12
# Шиба-ину            Трехцветный             Чарли           30            6
# Бостон-терьер       Черно-белый               Луи           25            5
# Френч бульдог       Белый                   Белль           35            8
# Хаски               Серо-белый               Сади           45           12
# Акита               Коричневый              Сэнди           60           30
#
#                                         Date of Birth  Height (m)         BMI
# Breed               Color
# Лабрадор            Шоколадный             2015-02-10        0.60   83.333333
# Бульдог             Палевый                2018-06-05        0.40  156.250000
# Далматин            Черно-белый            2017-11-20        0.55   66.115702
# Ши-тцу              Белый                  2019-04-15        0.25   80.000000
# Йоркширский терьер  Серый                  2020-09-30        0.20   75.000000
# Лабрадор            Абрикосовый            2016-03-25        0.58   80.261593
# Чихуахуа            Черный                 2019-08-12        0.20   75.000000
# Шарпей              Коричневый             2018-01-03        0.40   93.750000
# Бассет-хаунд        Трехцветный            2020-05-19        0.30  111.111111
# Померанский         Оранжевый              2017-09-28        0.25   64.000000
# Золотистый ретривер Золотистый             2016-07-14        0.60   69.444444
# Бордер-колли        Черно-белый            2019-02-08        0.50   72.000000
# Боксер              Тигровый               2017-04-22        0.55   99.173554
# Ротвейлер           Черный и рыжий         2015-09-07        0.70   81.632653
# Доберман            Черный и коричневый    2016-12-30        0.45   59.259259
# Шиба-ину            Трехцветный            2018-11-17        0.30   66.666667
# Бостон-терьер       Черно-белый            2020-03-08        0.25   80.000000
# Френч бульдог       Белый                  2019-10-12        0.35   65.306122
# Хаски               Серо-белый             2016-06-23        0.45   59.259259
# Акита               Коричневый             2015-08-02        0.60   83.333333

# %%
dogs_ind3.loc[["Лабрадор", "Боксер"]]
# Out:
#                        Name  Height (cm)  Weight (kg) Date of Birth  \
# Breed    Color
# Лабрадор Шоколадный    Сноу           60           30    2015-02-10
#          Абрикосовый   Мило           58           27    2016-03-25
# Боксер   Тигровый     Чарли           55           30    2017-04-22
#
#                       Height (m)        BMI
# Breed    Color
# Лабрадор Шоколадный         0.60  83.333333
#          Абрикосовый        0.58  80.261593
# Боксер   Тигровый           0.55  99.173554

# %%
dogs_ind3.loc[[("Лабрадор", "Шоколадный"), ("Боксер", "Тигровый")]]
# Out:
#                       Name  Height (cm)  Weight (kg) Date of Birth  \
# Breed    Color
# Лабрадор Шоколадный   Сноу           60           30    2015-02-10
# Боксер   Тигровый    Чарли           55           30    2017-04-22
#
#                      Height (m)        BMI
# Breed    Color
# Лабрадор Шоколадный        0.60  83.333333
# Боксер   Тигровый          0.55  99.173554

# %%
dogs_ind3.sort_index()
# Out:
#                                              Name  Height (cm)  Weight (kg)  \
# Breed               Color
# Акита               Коричневый              Сэнди           60           30
# Бассет-хаунд        Трехцветный             Тедди           30           10
# Боксер              Тигровый                Чарли           55           30
# Бордер-колли        Черно-белый            Джесси           50           18
# Бостон-терьер       Черно-белый               Луи           25            5
# Бульдог             Палевый                  Рекс           40           25
# Далматин            Черно-белый              Макс           55           20
# Доберман            Черный и коричневый    Оливер           45           12
# Золотистый ретривер Золотистый             Бентли           60           25
# Йоркширский терьер  Серый                    Джек           20            3
# Лабрадор            Абрикосовый              Мило           58           27
#                     Шоколадный               Сноу           60           30
# Померанский         Оранжевый                Макс           25            4
# Ротвейлер           Черный и рыжий       Максимус           70           40
# Френч бульдог       Белый                   Белль           35            8
# Хаски               Серо-белый               Сади           45           12
# Чихуахуа            Черный                  Бэйли           20            3
# Шарпей              Коричневый               Лола           40           15
# Ши-тцу              Белый                    Луна           25            5
# Шиба-ину            Трехцветный             Чарли           30            6
#
#                                         Date of Birth  Height (m)         BMI
# Breed               Color
# Акита               Коричневый             2015-08-02        0.60   83.333333
# Бассет-хаунд        Трехцветный            2020-05-19        0.30  111.111111
# Боксер              Тигровый               2017-04-22        0.55   99.173554
# Бордер-колли        Черно-белый            2019-02-08        0.50   72.000000
# Бостон-терьер       Черно-белый            2020-03-08        0.25   80.000000
# Бульдог             Палевый                2018-06-05        0.40  156.250000
# Далматин            Черно-белый            2017-11-20        0.55   66.115702
# Доберман            Черный и коричневый    2016-12-30        0.45   59.259259
# Золотистый ретривер Золотистый             2016-07-14        0.60   69.444444
# Йоркширский терьер  Серый                  2020-09-30        0.20   75.000000
# Лабрадор            Абрикосовый            2016-03-25        0.58   80.261593
#                     Шоколадный             2015-02-10        0.60   83.333333
# Померанский         Оранжевый              2017-09-28        0.25   64.000000
# Ротвейлер           Черный и рыжий         2015-09-07        0.70   81.632653
# Френч бульдог       Белый                  2019-10-12        0.35   65.306122
# Хаски               Серо-белый             2016-06-23        0.45   59.259259
# Чихуахуа            Черный                 2019-08-12        0.20   75.000000
# Шарпей              Коричневый             2018-01-03        0.40   93.750000
# Ши-тцу              Белый                  2019-04-15        0.25   80.000000
# Шиба-ину            Трехцветный            2018-11-17        0.30   66.666667

# %%
dogs_ind3.sort_index(level=["Color", "Breed"], ascending=[True, False])
# Out:
#                                              Name  Height (cm)  Weight (kg)  \
# Breed               Color
# Лабрадор            Абрикосовый              Мило           58           27
# Ши-тцу              Белый                    Луна           25            5
# Френч бульдог       Белый                   Белль           35            8
# Золотистый ретривер Золотистый             Бентли           60           25
# Шарпей              Коричневый               Лола           40           15
# Акита               Коричневый              Сэнди           60           30
# Померанский         Оранжевый                Макс           25            4
# Бульдог             Палевый                  Рекс           40           25
# Хаски               Серо-белый               Сади           45           12
# Йоркширский терьер  Серый                    Джек           20            3
# Боксер              Тигровый                Чарли           55           30
# Шиба-ину            Трехцветный             Чарли           30            6
# Бассет-хаунд        Трехцветный             Тедди           30           10
# Далматин            Черно-белый              Макс           55           20
# Бостон-терьер       Черно-белый               Луи           25            5
# Бордер-колли        Черно-белый            Джесси           50           18
# Чихуахуа            Черный                  Бэйли           20            3
# Доберман            Черный и коричневый    Оливер           45           12
# Ротвейлер           Черный и рыжий       Максимус           70           40
# Лабрадор            Шоколадный               Сноу           60           30
#
#                                         Date of Birth  Height (m)         BMI
# Breed               Color
# Лабрадор            Абрикосовый            2016-03-25        0.58   80.261593
# Ши-тцу              Белый                  2019-04-15        0.25   80.000000
# Френч бульдог       Белый                  2019-10-12        0.35   65.306122
# Золотистый ретривер Золотистый             2016-07-14        0.60   69.444444
# Шарпей              Коричневый             2018-01-03        0.40   93.750000
# Акита               Коричневый             2015-08-02        0.60   83.333333
# Померанский         Оранжевый              2017-09-28        0.25   64.000000
# Бульдог             Палевый                2018-06-05        0.40  156.250000
# Хаски               Серо-белый             2016-06-23        0.45   59.259259
# Йоркширский терьер  Серый                  2020-09-30        0.20   75.000000
# Боксер              Тигровый               2017-04-22        0.55   99.173554
# Шиба-ину            Трехцветный            2018-11-17        0.30   66.666667
# Бассет-хаунд        Трехцветный            2020-05-19        0.30  111.111111
# Далматин            Черно-белый            2017-11-20        0.55   66.115702
# Бостон-терьер       Черно-белый            2020-03-08        0.25   80.000000
# Бордер-колли        Черно-белый            2019-02-08        0.50   72.000000
# Чихуахуа            Черный                 2019-08-12        0.20   75.000000
# Доберман            Черный и коричневый    2016-12-30        0.45   59.259259
# Ротвейлер           Черный и рыжий         2015-09-07        0.70   81.632653
# Лабрадор            Шоколадный             2015-02-10        0.60   83.333333

# %% [markdown]
# ### Срезы и выборки с `.loc` и `.iloc`

# %%
breeds = ['Лабрадор', 'Бульдог', 'Далматин', 'Ши-тцу', 'Йоркширский терьер', 'Лабрадор', 'Чихуахуа', 'Шарпей', 'Бассет-хаунд', 'Померанский',
              'Золотистый ретривер', 'Бордер-колли', 'Боксер', 'Ротвейлер', 'Доберман', 'Шиба-ину', 'Бостон-терьер', 'Френч бульдог', 'Хаски', 'Акита']

# %%
breeds
# Out:
# ['Лабрадор',
#  'Бульдог',
#  'Далматин',
#  'Ши-тцу',
#  'Йоркширский терьер',
#  'Лабрадор',
#  'Чихуахуа',
#  'Шарпей',
#  'Бассет-хаунд',
#  'Померанский',
#  'Золотистый ретривер',
#  'Бордер-колли',
#  'Боксер',
#  'Ротвейлер',
#  'Доберман',
#  'Шиба-ину',
#  'Бостон-терьер',
#  'Френч бульдог',
#  'Хаски',
#  'Акита']

# %%
breeds[2:5]
# Out:
# ['Далматин', 'Ши-тцу', 'Йоркширский терьер']

# %%
breeds[:3]
# Out:
# ['Лабрадор', 'Бульдог', 'Далматин']

# %%
breeds[:]
# Out:
# ['Лабрадор',
#  'Бульдог',
#  'Далматин',
#  'Ши-тцу',
#  'Йоркширский терьер',
#  'Лабрадор',
#  'Чихуахуа',
#  'Шарпей',
#  'Бассет-хаунд',
#  'Померанский',
#  'Золотистый ретривер',
#  'Бордер-колли',
#  'Боксер',
#  'Ротвейлер',
#  'Доберман',
#  'Шиба-ину',
#  'Бостон-терьер',
#  'Френч бульдог',
#  'Хаски',
#  'Акита']

# %%
breeds[::-1]
# Out:
# ['Акита',
#  'Хаски',
#  'Френч бульдог',
#  'Бостон-терьер',
#  'Шиба-ину',
#  'Доберман',
#  'Ротвейлер',
#  'Боксер',
#  'Бордер-колли',
#  'Золотистый ретривер',
#  'Померанский',
#  'Бассет-хаунд',
#  'Шарпей',
#  'Чихуахуа',
#  'Лабрадор',
#  'Йоркширский терьер',
#  'Ши-тцу',
#  'Далматин',
#  'Бульдог',
#  'Лабрадор']

# %%
dogs_sort = dogs.set_index(["Breed", "Color"]).sort_index()

# %%
dogs_sort
# Out:
#                                              Name  Height (cm)  Weight (kg)  \
# Breed               Color
# Акита               Коричневый              Сэнди           60           30
# Бассет-хаунд        Трехцветный             Тедди           30           10
# Боксер              Тигровый                Чарли           55           30
# Бордер-колли        Черно-белый            Джесси           50           18
# Бостон-терьер       Черно-белый               Луи           25            5
# Бульдог             Палевый                  Рекс           40           25
# Далматин            Черно-белый              Макс           55           20
# Доберман            Черный и коричневый    Оливер           45           12
# Золотистый ретривер Золотистый             Бентли           60           25
# Йоркширский терьер  Серый                    Джек           20            3
# Лабрадор            Абрикосовый              Мило           58           27
#                     Шоколадный               Сноу           60           30
# Померанский         Оранжевый                Макс           25            4
# Ротвейлер           Черный и рыжий       Максимус           70           40
# Френч бульдог       Белый                   Белль           35            8
# Хаски               Серо-белый               Сади           45           12
# Чихуахуа            Черный                  Бэйли           20            3
# Шарпей              Коричневый               Лола           40           15
# Ши-тцу              Белый                    Луна           25            5
# Шиба-ину            Трехцветный             Чарли           30            6
#
#                                         Date of Birth  Height (m)         BMI
# Breed               Color
# Акита               Коричневый             2015-08-02        0.60   83.333333
# Бассет-хаунд        Трехцветный            2020-05-19        0.30  111.111111
# Боксер              Тигровый               2017-04-22        0.55   99.173554
# Бордер-колли        Черно-белый            2019-02-08        0.50   72.000000
# Бостон-терьер       Черно-белый            2020-03-08        0.25   80.000000
# Бульдог             Палевый                2018-06-05        0.40  156.250000
# Далматин            Черно-белый            2017-11-20        0.55   66.115702
# Доберман            Черный и коричневый    2016-12-30        0.45   59.259259
# Золотистый ретривер Золотистый             2016-07-14        0.60   69.444444
# Йоркширский терьер  Серый                  2020-09-30        0.20   75.000000
# Лабрадор            Абрикосовый            2016-03-25        0.58   80.261593
#                     Шоколадный             2015-02-10        0.60   83.333333
# Померанский         Оранжевый              2017-09-28        0.25   64.000000
# Ротвейлер           Черный и рыжий         2015-09-07        0.70   81.632653
# Френч бульдог       Белый                  2019-10-12        0.35   65.306122
# Хаски               Серо-белый             2016-06-23        0.45   59.259259
# Чихуахуа            Черный                 2019-08-12        0.20   75.000000
# Шарпей              Коричневый             2018-01-03        0.40   93.750000
# Ши-тцу              Белый                  2019-04-15        0.25   80.000000
# Шиба-ину            Трехцветный            2018-11-17        0.30   66.666667

# %%
dogs_sort.loc["Бульдог":"Лабрадор"]
# Out:
#                                            Name  Height (cm)  Weight (kg)  \
# Breed               Color
# Бульдог             Палевый                Рекс           40           25
# Далматин            Черно-белый            Макс           55           20
# Доберман            Черный и коричневый  Оливер           45           12
# Золотистый ретривер Золотистый           Бентли           60           25
# Йоркширский терьер  Серый                  Джек           20            3
# Лабрадор            Абрикосовый            Мило           58           27
#                     Шоколадный             Сноу           60           30
#
#                                         Date of Birth  Height (m)         BMI
# Breed               Color
# Бульдог             Палевый                2018-06-05        0.40  156.250000
# Далматин            Черно-белый            2017-11-20        0.55   66.115702
# Доберман            Черный и коричневый    2016-12-30        0.45   59.259259
# Золотистый ретривер Золотистый             2016-07-14        0.60   69.444444
# Йоркширский терьер  Серый                  2020-09-30        0.20   75.000000
# Лабрадор            Абрикосовый            2016-03-25        0.58   80.261593
#                     Шоколадный             2015-02-10        0.60   83.333333

# %%
dogs_sort.loc["Палевый":"Шоколадный"]
# Out:
#                                   Name  Height (cm)  Weight (kg)  \
# Breed         Color
# Померанский   Оранжевый           Макс           25            4
# Ротвейлер     Черный и рыжий  Максимус           70           40
# Френч бульдог Белый              Белль           35            8
# Хаски         Серо-белый          Сади           45           12
# Чихуахуа      Черный             Бэйли           20            3
# Шарпей        Коричневый          Лола           40           15
# Ши-тцу        Белый               Луна           25            5
# Шиба-ину      Трехцветный        Чарли           30            6
#
#                              Date of Birth  Height (m)        BMI
# Breed         Color
# Померанский   Оранжевый         2017-09-28        0.25  64.000000
# Ротвейлер     Черный и рыжий    2015-09-07        0.70  81.632653
# Френч бульдог Белый             2019-10-12        0.35  65.306122
# Хаски         Серо-белый        2016-06-23        0.45  59.259259
# Чихуахуа      Черный            2019-08-12        0.20  75.000000
# Шарпей        Коричневый        2018-01-03        0.40  93.750000
# Ши-тцу        Белый             2019-04-15        0.25  80.000000
# Шиба-ину      Трехцветный       2018-11-17        0.30  66.666667

# %%
dogs_sort.loc[("Бульдог", "Палевый"):("Лабрадор", "Шоколадный")]
# Out:
#                                            Name  Height (cm)  Weight (kg)  \
# Breed               Color
# Бульдог             Палевый                Рекс           40           25
# Далматин            Черно-белый            Макс           55           20
# Доберман            Черный и коричневый  Оливер           45           12
# Золотистый ретривер Золотистый           Бентли           60           25
# Йоркширский терьер  Серый                  Джек           20            3
# Лабрадор            Абрикосовый            Мило           58           27
#                     Шоколадный             Сноу           60           30
#
#                                         Date of Birth  Height (m)         BMI
# Breed               Color
# Бульдог             Палевый                2018-06-05        0.40  156.250000
# Далматин            Черно-белый            2017-11-20        0.55   66.115702
# Доберман            Черный и коричневый    2016-12-30        0.45   59.259259
# Золотистый ретривер Золотистый             2016-07-14        0.60   69.444444
# Йоркширский терьер  Серый                  2020-09-30        0.20   75.000000
# Лабрадор            Абрикосовый            2016-03-25        0.58   80.261593
#                     Шоколадный             2015-02-10        0.60   83.333333

# %%
dogs_sort.loc[:,"Name": "Height (cm)"]
# Out:
#                                              Name  Height (cm)
# Breed               Color
# Акита               Коричневый              Сэнди           60
# Бассет-хаунд        Трехцветный             Тедди           30
# Боксер              Тигровый                Чарли           55
# Бордер-колли        Черно-белый            Джесси           50
# Бостон-терьер       Черно-белый               Луи           25
# Бульдог             Палевый                  Рекс           40
# Далматин            Черно-белый              Макс           55
# Доберман            Черный и коричневый    Оливер           45
# Золотистый ретривер Золотистый             Бентли           60
# Йоркширский терьер  Серый                    Джек           20
# Лабрадор            Абрикосовый              Мило           58
#                     Шоколадный               Сноу           60
# Померанский         Оранжевый                Макс           25
# Ротвейлер           Черный и рыжий       Максимус           70
# Френч бульдог       Белый                   Белль           35
# Хаски               Серо-белый               Сади           45
# Чихуахуа            Черный                  Бэйли           20
# Шарпей              Коричневый               Лола           40
# Ши-тцу              Белый                    Луна           25
# Шиба-ину            Трехцветный             Чарли           30

# %%
dogs_sort.loc["Бульдог":"Лабрадор","Name": "Height (cm)"]
# Out:
#                                            Name  Height (cm)
# Breed               Color
# Бульдог             Палевый                Рекс           40
# Далматин            Черно-белый            Макс           55
# Доберман            Черный и коричневый  Оливер           45
# Золотистый ретривер Золотистый           Бентли           60
# Йоркширский терьер  Серый                  Джек           20
# Лабрадор            Абрикосовый            Мило           58
#                     Шоколадный             Сноу           60

# %%
dogs = dogs_sort.set_index("Date of Birth").sort_index()
dogs
# Out:
#                    Name  Height (cm)  Weight (kg)  Height (m)         BMI
# Date of Birth
# 2015-02-10         Сноу           60           30        0.60   83.333333
# 2015-08-02        Сэнди           60           30        0.60   83.333333
# 2015-09-07     Максимус           70           40        0.70   81.632653
# 2016-03-25         Мило           58           27        0.58   80.261593
# 2016-06-23         Сади           45           12        0.45   59.259259
# 2016-07-14       Бентли           60           25        0.60   69.444444
# 2016-12-30       Оливер           45           12        0.45   59.259259
# 2017-04-22        Чарли           55           30        0.55   99.173554
# 2017-09-28         Макс           25            4        0.25   64.000000
# 2017-11-20         Макс           55           20        0.55   66.115702
# 2018-01-03         Лола           40           15        0.40   93.750000
# 2018-06-05         Рекс           40           25        0.40  156.250000
# 2018-11-17        Чарли           30            6        0.30   66.666667
# 2019-02-08       Джесси           50           18        0.50   72.000000
# 2019-04-15         Луна           25            5        0.25   80.000000
# 2019-08-12        Бэйли           20            3        0.20   75.000000
# 2019-10-12        Белль           35            8        0.35   65.306122
# 2020-03-08          Луи           25            5        0.25   80.000000
# 2020-05-19        Тедди           30           10        0.30  111.111111
# 2020-09-30         Джек           20            3        0.20   75.000000

# %%
dogs.loc["2016-01-01":"2018-02-15"]
# Out:
#                  Name  Height (cm)  Weight (kg)  Height (m)        BMI
# Date of Birth
# 2016-03-25       Мило           58           27        0.58  80.261593
# 2016-06-23       Сади           45           12        0.45  59.259259
# 2016-07-14     Бентли           60           25        0.60  69.444444
# 2016-12-30     Оливер           45           12        0.45  59.259259
# 2017-04-22      Чарли           55           30        0.55  99.173554
# 2017-09-28       Макс           25            4        0.25  64.000000
# 2017-11-20       Макс           55           20        0.55  66.115702
# 2018-01-03       Лола           40           15        0.40  93.750000

# %%
dogs.loc["2016":"2018"]
# Out:
#                  Name  Height (cm)  Weight (kg)  Height (m)        BMI
# Date of Birth
# 2016-03-25       Мило           58           27        0.58  80.261593
# 2016-06-23       Сади           45           12        0.45  59.259259
# 2016-07-14     Бентли           60           25        0.60  69.444444
# 2016-12-30     Оливер           45           12        0.45  59.259259
# 2017-04-22      Чарли           55           30        0.55  99.173554
# 2017-09-28       Макс           25            4        0.25  64.000000
# 2017-11-20       Макс           55           20        0.55  66.115702

# %%
dogs.iloc[2:5, 1:3]
# Out:
#                Height (cm)  Weight (kg)
# Date of Birth
# 2015-09-07              70           40
# 2016-03-25              58           27
# 2016-06-23              45           12
